# %% [markdown]
# # Demand forecasting with the Temporal Fusion Transformer

# %%
import os
import warnings

warnings.filterwarnings("ignore")  # avoid printing out absolute paths
# %matplotlib inline
import copy
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch

from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

from pytorch_forecasting import Baseline, NBeats, TimeSeriesDataSet,TemporalFusionTransformer
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE

# %%
def generateDummyData(peopleCount,numOfPersonas,strtDate,endDate,frequency):
    date_rng = pd.date_range(start=strtDate, end=endDate, freq=frequency)
    df = pd.DataFrame(date_rng, columns=['date'])

    for userNum in range(0, peopleCount):
        df['counter'] = range(1, 1 + len(df))           # Row ID
        df['userID'] = userNum                          # UserID

        userPersona = userNum%numOfPersonas+1
        #df ['amount'] = 1+(df['counter']%(userPersona+2)==0)*1
        df ['amount'] = 1+(df['counter']%(2)==0)*1

        if userNum == 0:
            finalDf = df.copy()  # Important - this is how you copy dataframes
        else:
            finalDf = finalDf.append(df, ignore_index=True)
    return finalDf

# %%
# Generate dummy data
data = generateDummyData(peopleCount=20,numOfPersonas=1,strtDate='1/1/18',endDate='31/12/21',frequency='d')

# add time index where 0 is the earliest date.
data["time_idx"] = data["date"].apply(pd.Timestamp.toordinal)
data["time_idx"] -= data["time_idx"].min()
data.head()
# Out:
#         date  counter  userID  amount  time_idx
# 0 2018-01-01        1       0       1         0
# 1 2018-01-02        2       0       2         1
# 2 2018-01-03        3       0       1         2
# 3 2018-01-04        4       0       2         3
# 4 2018-01-05        5       0       1         4

# %% [markdown]
# ### Review dummy data

# %%
import seaborn as sns
plt.figure(figsize=(15,5))  # width and height
sns.set_theme(style="whitegrid")
palette = sns.color_palette("rocket_r")

# Plot the responses for different events and regions
df=data[(data['date']<='28/02/2018') & (data['userID'].isin([1, 3,6]))]  # Forgetting the brackets always trips me up!

g1 = sns.relplot(
    data=df,
    x="date", y="amount",
    hue="userID", col="userID",
    kind="line",
    height=5, aspect=2, facet_kws=dict(sharex=False), col_wrap=1, 
)

# %%
data = generate_ar_data(seasonality=10.0, timesteps=400, n_series=100, seed=42)
data["static"] = 2
data["date"] = pd.Timestamp("2020-01-01") + pd.to_timedelta(data.time_idx, "D")
data.head()
# Out:
#    series  time_idx     value  static       date
# 0       0         0 -0.000000       2 2020-01-01
# 1       0         1 -0.046501       2 2020-01-02
# 2       0         2 -0.097796       2 2020-01-03
# 3       0         3 -0.144397       2 2020-01-04
# 4       0         4 -0.177954       2 2020-01-05

# %%
data['amount'] = data['amount'].astype(float)
data.dtypes
# Out:
# time_idx             int64
# date        datetime64[ns]
# counter              int64
# userID               int64
# amount             float64
# dtype: object

# %%
# create dataset and dataloaders
max_encoder_length = 30
max_prediction_length = 7

training_cutoff = data["time_idx"].max() - max_prediction_length

context_length = max_encoder_length
prediction_length = max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="amount",
    categorical_encoders={"userID": NaNLabelEncoder().fit(data.userID)},
    group_ids=["userID"],
    # only unknown variable is "value" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["amount"],
    max_encoder_length=context_length,
    max_prediction_length=prediction_length,
)

validation = TimeSeriesDataSet.from_dataset(training, data, min_prediction_idx=training_cutoff + 1)
batch_size = 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0)

# %%
# Move column to the front - Inserted by me
def move_column_inplace(df, col, pos):
    col = df.pop(col)
    df.insert(pos, col.name, col)

move_column_inplace(data,"time_idx",0)

# %%
# calculate baseline absolute error
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
SMAPE()(baseline_predictions, actuals)
# Out:
# tensor(0.3810)

# %%
pl.seed_everything(42)
trainer = pl.Trainer(gpus=1, gradient_clip_val=0.01)
net = NBeats.from_dataset(training, learning_rate=3e-2, weight_decay=1e-2, widths=[64, 512], backcast_loss_ratio=0.1)
# Out:
# Global seed set to 42
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(net, train_dataloader=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
net.hparams.learning_rate = res.suggestion()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Global seed set to 42
# Finding best initial lr: 100%|███████████████████████████████████████████████████████| 100/100 [00:12<00:00,  8.20it/s]Restoring states from the checkpoint path at E:\projects\github\pytorch\lr_find_temp_model_19169c7b-2c6c-4aa0-97b3-58f178d9c01b.ckpt
# Finding best initial lr: 100%|███████████████████████████████████████████████████████| 100/100 [00:12<00:00,  8.14it/s]
# suggested learning rate: 0.0022387211385683386

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=20, verbose=False, mode="min")
trainer = pl.Trainer(
    max_epochs=100,
    gpus=1,
    weights_summary="full",
    gradient_clip_val=0.01,
    callbacks=[early_stop_callback],
    limit_train_batches=30,
)


net = NBeats.from_dataset(
    training,
    learning_rate=0.002,
    log_interval=10,
    log_val_interval=1,
    weight_decay=1e-2,
    widths=[64, 512],
    backcast_loss_ratio=1.0,
)

trainer.fit(
    net,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                    | Type                | Params
# -----------------------------------------------------------------
# 0  | loss                    | MASE                | 0
# 1  | logging_metrics         | ModuleList          | 0
# 2  | logging_metrics.0       | SMAPE               | 0
# 3  | logging_metrics.1       | MAE                 | 0
# 4  | logging_metrics.2       | RMSE                | 0
# 5  | logging_metrics.3       | MAPE                | 0
# 6  | logging_metrics.4       | MASE                | 0
# 7  | net_blocks              | ModuleList          | 1.7 M
# 8  | net_blocks.0            | NBEATSTrendBlock    | 10.5 K
# 9  | net_blocks.0.fc         | Sequential          | 10.3 K
# 10 | net_blocks.0.fc.0       | Linear              | 2.0 K
# 11 | net_blocks.0.fc.1       | ReLU                | 0
# 12 | net_blocks.0.fc.2       | Sequential          | 4.2 K
# 13 | net_blocks.0.fc.2.0     | Dropout             | 0
# 14 | net_blocks.0.fc.2.1     | Linear              | 4.2 K
# 15 | net_blocks.0.fc.3       | ReLU                | 0
# 16 | net_blocks.0.fc.4       | Sequential          | 4.2 K
# 17 | net_blocks.0.fc.4.0     | Dropout             | 0
# 18 | net_blocks.0.fc.4.1     | Linear              | 4.2 K
# 19 | net_blocks.0.fc.5       | ReLU                | 0
# 20 | net_blocks.0.theta_f_fc | Linear              | 192
# 21 | net_blocks.1            | NBEATSTrendBlock    | 10.5 K
# 22 | net_blocks.1.fc         | Sequential          | 10.3 K
# 23 | net_blocks.1.fc.0       | Linear              | 2.0 K
# 24 | net_blocks.1.fc.1       | ReLU                | 0
# 25 | net_blocks.1.fc.2       | Sequential          | 4.2 K
# 26 | net_blocks.1.fc.2.0     | Dropout             | 0
# 27 | net_blocks.1.fc.2.1     | Linear              | 4.2 K
# 28 | net_blocks.1.fc.3       | ReLU                | 0
# 29 | net_blocks.1.fc.4       | Sequential          | 4.2 K
# 30 | net_blocks.1.fc.4.0     | Dropout             | 0
# 31 | net_blocks.1.fc.4.1     | Linear              | 4.2 K
# 32 | net_blocks.1.fc.5       | ReLU                | 0
# 33 | net_blocks.1.theta_f_fc | Linear              | 192
# 34 | net_blocks.2            | NBEATSTrendBlock    | 10.5 K
# 35 | net_blocks.2.fc         | Sequential          | 10.3 K
# 36 | net_blocks.2.fc.0       | Linear              | 2.0 K
# 37 | net_blocks.2.fc.1       | ReLU                | 0
# 38 | net_blocks.2.fc.2       | Sequential          | 4.2 K
# 39 | net_blocks.2.fc.2.0     | Dropout             | 0
# 40 | net_blocks.2.fc.2.1     | Linear              | 4.2 K
# 41 | net_blocks.2.fc.3       | ReLU                | 0
# 42 | net_blocks.2.fc.4       | Sequential          | 4.2 K
# 43 | net_blocks.2.fc.4.0     | Dropout             | 0
# 44 | net_blocks.2.fc.4.1     | Linear              | 4.2 K
# 45 | net_blocks.2.fc.5       | ReLU                | 0
# 46 | net_blocks.2.theta_f_fc | Linear              | 192
# 47 | net_blocks.3            | NBEATSSeasonalBlock | 544 K
# 48 | net_blocks.3.fc         | Sequential          | 541 K
# 49 | net_blocks.3.fc.0       | Linear              | 15.9 K
# 50 | net_blocks.3.fc.1       | ReLU                | 0
# 51 | net_blocks.3.fc.2       | Sequential          | 262 K
# 52 | net_blocks.3.fc.2.0     | Dropout             | 0
# 53 | net_blocks.3.fc.2.1     | Linear              | 262 K
# 54 | net_blocks.3.fc.3       | ReLU                | 0
# 55 | net_blocks.3.fc.4       | Sequential          | 262 K
# 56 | net_blocks.3.fc.4.0     | Dropout             | 0
# 57 | net_blocks.3.fc.4.1     | Linear              | 262 K
# 58 | net_blocks.3.fc.5       | ReLU                | 0
# 59 | net_blocks.3.theta_f_fc | Linear              | 3.6 K
# 60 | net_blocks.4            | NBEATSSeasonalBlock | 544 K
# 61 | net_blocks.4.fc         | Sequential          | 541 K
# 62 | net_blocks.4.fc.0       | Linear              | 15.9 K
# 63 | net_blocks.4.fc.1       | ReLU                | 0
# 64 | net_blocks.4.fc.2       | Sequential          | 262 K
# 65 | net_blocks.4.fc.2.0     | Dropout             | 0
# 66 | net_blocks.4.fc.2.1     | Linear              | 262 K
# 67 | net_blocks.4.fc.3       | ReLU                | 0
# 68 | net_blocks.4.fc.4       | Sequential          | 262 K
# 69 | net_blocks.4.fc.4.0     | Dropout             | 0
# 70 | net_blocks.4.fc.4.1     | Linear              | 262 K
# 71 | net_blocks.4.fc.5       | ReLU                | 0
# 72 | net_blocks.4.theta_f_fc | Linear              | 3.6 K
# 73 | net_blocks.5            | NBEATSSeasonalBlock | 544 K
# 74 | net_blocks.5.fc         | Sequential          | 541 K
# 75 | net_blocks.5.fc.0       | Linear              | 15.9 K
# 76 | net_blocks.5.fc.1       | ReLU                | 0
# 77 | net_blocks.5.fc.2       | Sequential          | 262 K
# 78 | net_blocks.5.fc.2.0     | Dropout             | 0
# 79 | net_blocks.5.fc.2.1     | Linear              | 262 K
# 80 | net_blocks.5.fc.3       | ReLU                | 0
# 81 | net_blocks.5.fc.4       | Sequential          | 262 K
# 82 | net_blocks.5.fc.4.0     | Dropout             | 0
# 83 | net_blocks.5.fc.4.1     | Linear              | 262 K
# 84 | net_blocks.5.fc.5       | ReLU                | 0
# 85 | net_blocks.5.theta_f_fc | Linear              | 3.6 K
# -----------------------------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# 6.663     Total estimated model params size (MB)
# Global seed set to 42
# Epoch 0:  97%|████████████████████████████ | 30/31 [00:04<00:00,  6.02it/s, loss=0.486, v_num=4, train_loss_step=0.460]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█████████████| 31/31 [00:05<00:00,  5.91it/s, loss=0.486, v_num=4, train_loss_step=0.460, val_loss=0.471]
# Epoch 1:  97%|▉| 30/31 [00:04<00:00,  6.58it/s, loss=0.458, v_num=4, train_loss_step=0.439, val_loss=0.471, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 31/31 [00:04<00:00,  6.42it/s, loss=0.458, v_num=4, train_loss_step=0.439, val_loss=0.434, train_loss_
# Epoch 2:  97%|▉| 30/31 [00:04<00:00,  6.72it/s, loss=0.449, v_num=4, train_loss_step=0.428, val_loss=0.434, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 31/31 [00:04<00:00,  6.52it/s, loss=0.449, v_num=4, train_loss_step=0.428, val_loss=0.424, train_loss_
# Epoch 3:  97%|▉| 30/31 [00:04<00:00,  6.58it/s, loss=0.446, v_num=4, train_loss_step=0.429, val_loss=0.424, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 31/31 [00:04<00:00,  6.40it/s, loss=0.446, v_num=4, train_loss_step=0.429, val_loss=0.425, train_loss_
# Epoch 4:  97%|▉| 30/31 [00:04<00:00,  6.76it/s, loss=0.445, v_num=4, train_loss_step=0.428, val_loss=0.425, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 31/31 [00:04<00:00,  6.62it/s, loss=0.445, v_num=4, train_loss_step=0.428, val_loss=0.427, train_loss_
# Epoch 5:  97%|▉| 30/31 [00:04<00:00,  6.76it/s, loss=0.444, v_num=4, train_loss_step=0.426, val_loss=0.427, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 31/31 [00:04<00:00,  6.60it/s, loss=0.444, v_num=4, train_loss_step=0.426, val_loss=0.426, train_loss_
# Epoch 6:  97%|▉| 30/31 [00:04<00:00,  6.35it/s, loss=0.444, v_num=4, train_loss_step=0.427, val_loss=0.426, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 31/31 [00:05<00:00,  6.03it/s, loss=0.444, v_num=4, train_loss_step=0.427, val_loss=0.426, train_loss_
# Epoch 7:  97%|▉| 30/31 [00:04<00:00,  6.43it/s, loss=0.443, v_num=4, train_loss_step=0.426, val_loss=0.426, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 31/31 [00:04<00:00,  6.30it/s, loss=0.443, v_num=4, train_loss_step=0.426, val_loss=0.426, train_loss_
# Epoch 8:  97%|▉| 30/31 [00:04<00:00,  6.72it/s, loss=0.443, v_num=4, train_loss_step=0.426, val_loss=0.426, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 31/31 [00:04<00:00,  6.53it/s, loss=0.443, v_num=4, train_loss_step=0.426, val_loss=0.428, train_loss_
# Epoch 9:  97%|▉| 30/31 [00:04<00:00,  6.65it/s, loss=0.443, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 31/31 [00:04<00:00,  6.48it/s, loss=0.443, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss_
# Epoch 10:  97%|▉| 30/31 [00:04<00:00,  6.63it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 31/31 [00:04<00:00,  6.48it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.427, train_loss
# Epoch 11:  97%|▉| 30/31 [00:04<00:00,  6.32it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.427, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 31/31 [00:05<00:00,  6.19it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss
# Epoch 12:  97%|▉| 30/31 [00:04<00:00,  6.66it/s, loss=0.442, v_num=4, train_loss_step=0.426, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 31/31 [00:04<00:00,  6.49it/s, loss=0.442, v_num=4, train_loss_step=0.426, val_loss=0.428, train_loss
# Epoch 13:  97%|▉| 30/31 [00:04<00:00,  6.59it/s, loss=0.442, v_num=4, train_loss_step=0.426, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 31/31 [00:04<00:00,  6.44it/s, loss=0.442, v_num=4, train_loss_step=0.426, val_loss=0.428, train_loss
# Epoch 14:  97%|▉| 30/31 [00:04<00:00,  6.71it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 31/31 [00:04<00:00,  6.53it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.427, train_loss
# Epoch 15:  97%|▉| 30/31 [00:04<00:00,  6.68it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.427, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 31/31 [00:04<00:00,  6.49it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss
# Epoch 16:  97%|▉| 30/31 [00:04<00:00,  6.73it/s, loss=0.442, v_num=4, train_loss_step=0.424, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 31/31 [00:04<00:00,  6.21it/s, loss=0.442, v_num=4, train_loss_step=0.424, val_loss=0.428, train_loss
# Epoch 17:  97%|▉| 30/31 [00:04<00:00,  6.66it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 31/31 [00:04<00:00,  6.50it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.428, train_loss
# Epoch 18:  97%|▉| 30/31 [00:04<00:00,  6.66it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.428, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 31/31 [00:04<00:00,  6.50it/s, loss=0.442, v_num=4, train_loss_step=0.425, val_loss=0.426, train_loss
# Epoch 19:  97%|▉| 30/31 [00:04<00:00,  6.81it/s, loss=0.442, v_num=4, train_loss_step=0.424, val_loss=0.426, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 31/31 [00:04<00:00,  6.62it/s, loss=0.442, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss
# Epoch 20:  97%|▉| 30/31 [00:04<00:00,  6.67it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 31/31 [00:04<00:00,  6.53it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.426, train_loss
# Epoch 21:  97%|▉| 30/31 [00:04<00:00,  6.76it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.426, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 31/31 [00:04<00:00,  6.59it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss
# Epoch 22:  97%|▉| 30/31 [00:04<00:00,  6.67it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 31/31 [00:04<00:00,  6.53it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss
# Epoch 22: 100%|█| 31/31 [00:04<00:00,  6.33it/s, loss=0.441, v_num=4, train_loss_step=0.424, val_loss=0.427, train_loss

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NBeats.load_from_checkpoint(best_model_path)

# %%
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(0.4157)

# %%
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
raw_predictions
# Out:
# Output(prediction=tensor([[1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589],
#         [1.0344, 1.4758, 1.8646, 1.9490, 1.6978, 1.3101, 1.0589]]), backcast=tensor([[1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397],
#         [1.0144, 0.9881, 1.2631, 1.6926, 1.9974, 1.9696, 1.6295, 1.2174, 1.0217,
#          1.1708, 1.5410, 1.8496, 1.8629, 1.5660, 1.1695, 0.9504, 1.0486, 1.3699,
#          1.6669, 1.7317, 1.5530, 1.3181, 1.2598, 1.4658, 1.8009, 2.0021, 1.8798,
#          1.4708, 1.0266, 0.8397]]), trend=tensor([[1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023],
#         [1.4854, 1.4956, 1.5052, 1.5143, 1.5228, 1.5308, 1.5382, 1.5450, 1.5513,
#          1.5571, 1.5623, 1.5669, 1.5710, 1.5745, 1.5775, 1.5799, 1.5817, 1.5830,
#          1.5838, 1.5840, 1.5836, 1.5827, 1.5812, 1.5792, 1.5766, 1.5735, 1.5698,
#          1.5655, 1.5607, 1.5554, 1.5494, 1.5430, 1.5360, 1.5284, 1.5202, 1.5116,
#          1.5023]]), seasonality=tensor([[1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566],
#         [1.0290, 0.9925, 1.2579, 1.6783, 1.9746, 1.9388, 1.5914, 1.1724, 0.9704,
#          1.1137, 1.4788, 1.7827, 1.7919, 1.4915, 1.0920, 0.8705, 0.9668, 1.2869,
#          1.5832, 1.6477, 1.4694, 1.2354, 1.1786, 1.3866, 1.7243, 1.9287, 1.8100,
#          1.4053, 0.9659, 0.7844, 0.9850, 1.4328, 1.8287, 1.9206, 1.6775, 1.2985,
#          1.0566]]), generic=tensor([[1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000],
#         [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000,
#          1.5000]]))
